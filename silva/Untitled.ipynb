# %%
from taxadb.taxid import TaxID

# %%
taxid = TaxID(dbype='sqlite', dbname='/home/ahmed/projects/coral-microbiome/taxadb.sqlite')
# Out:
# Can't create database object: Database type 'None' not supported
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File /usr/local/lib/python3.8/dist-packages/taxadb/taxadb.py:39, in TaxaDB.__init__(self, **kwargs)
#      38 try:
# ---> 39     self.dbfact = DatabaseFactory(**kwargs)
#      40     self.database = self.dbfact.get_database()
#
# File /usr/local/lib/python3.8/dist-packages/taxadb/schema.py:143, in DatabaseFactory.__init__(self, config, **kwargs)
#     141 if self.get('dbtype') is None or self.get('dbtype') not in \
#     142         DatabaseFactory.SUPPORTED_DBS:
# --> 143     raise AttributeError(
#     144         "Database type '%s' not supported" % str(self.get('dbtype')))
#     145 if self.get('dbname') is None:
#
# AttributeError: Database type 'None' not supported
#
# During handling of the above exception, another exception occurred:
#
# ...
